# %%
# !pip install pandas dash jupyter jupyter_dash
# Out:
# Requirement already satisfied: pandas in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: dash in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (2.18.2)
# Requirement already satisfied: jupyter in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: jupyter_dash in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (6.5.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from dash) (59.6.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (8.3.1)
# Requirement already satisfied: blinker>=1.6.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from Werkzeug<3.1->dash) (3.0.3)
# Requirement already satisfied: notebook in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter) (7.5.0)
# Requirement already satisfied: jupyter-console in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter) (7.1.0)
# Requirement already satisfied: ipywidgets in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter) (4.5.0)
# Requirement already satisfied: ipython in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter_dash) (8.37.0)
# Requirement already satisfied: ansi2html in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter_dash) (1.9.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (2.12.0)
# Requirement already satisfied: packaging in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: six>=1.5 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: comm>=0.1.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: psutil>=5.7 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: decorator in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (2.19.2)
# Requirement already satisfied: stack_data in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: wcwidth in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: anyio in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: certifi in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: sniffio>=1.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.29.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbconvert->jupyter) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from stack_data->ipython->jupyter_dash) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure-eval in /home/ayjrin/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)

# %%
# DASH Framework for Jupyter
from jupyter_dash import JupyterDash
from dash import dcc, html
from dash.dependencies import Input, Output
from pprint import pformat
JupyterDash.infer_jupyter_proxy_config()

# URL Lib to make sure that our input is 'sane'
import urllib.parse

#TODO: import for your CRUD module
from CRUD_Python_Module import AnimalShelter



# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    # This element generates an HTML Heading with your name
    html.H1("Module 5 Asssignment - Adrian Tull"),
    # This Input statement sets up an Input field for the username.
    dcc.Input(
            id="input_user".format("text"),
            type="text",
            placeholder="input type {}".format("text")),
    # This Input statement sets up an Input field for the password.
    # This designation masks the user input on the screen.
    dcc.Input(
            id="input_passwd".format("password"),
            type="password",
            placeholder="input type {}".format("password")),
    # Create a button labeled 'Submit'. When the button is pressed
    # the n_clicks value will increment by 1. 
    html.Button('Submit', id='submit-val', n_clicks=0),
    # Generate a horizontal line separating our input from our
    # output element
    html.Hr(),
    # This sets up the output element for the dashboard. The
    # purpose of the stlye option is to make sure that the 
    # output will function like a regular text area and accept
    # newline ('\n') characters as line-breaks.
    html.Div(
        id="query-out", 
        style={
            'whiteSpace': 'pre-wrap',
            'fontFamily': 'monospace'
        }
    ),
    #TODO: insert unique identifier code here. Please Note: 
    # when you insert another HTML element here, you will need to 
    # add a comma to the previous line.
    dcc.Input(
        id="input_animal_id",
        type="text",
        placeholder="Enter animal id here"
    )
])

# Define callback to update output-block
# NOTE: While the name of the callback function doesn't matter,
# the order of the parameters in the callback function are the
# same as the order of Input methods in the @app.callback
# For the callback function below, the callback is grabing the
# information from the input_user and input_password entries, and
# then the value of the submit button (has it been pressed?)
@app.callback(
    Output('query-out', 'children'),
    [
        Input('input_user', 'value'),
        Input('input_passwd', 'value'),
        Input('input_animal_id', 'value'),
        Input(component_id='submit-val', component_property='n_clicks')]
)
def update_figure(inputUser,inputPass,animal_id, n_clicks):
    # This is used as a trigger to make sure that the callback doesn't
    # try and connect to the database until after the submit button
    # is pressed. Otherwise, every time a character was added to the 
    # username or password field, an attempt would be made to connect to 
    # the daabase with an incorrect username and password.
    if n_clicks > 0:
        ###########################
        # Data Manipulation / Model
        # use CRUD module to access MongoDB
        ##########################
        
        # Use the URLLIB to setup the username and password so that they
        # can be passed cleanly to the MongoDB handler.
        username = urllib.parse.quote_plus(inputUser)
        password = urllib.parse.quote_plus(inputPass)
        
        ## DEBUG STATEMENT - You can uncomment the next line to verify you
        ## are correctly entering your username and password prior to continuing
        ## to build the callback function.
        ## return f'Output: {inputUser}, {inputPass}'

        #TODO: Instantiate CRUD object with above authentication username and 
        # password values
        shelter = AnimalShelter(username=username, password=password)
        if shelter:
            pass
        else:
            return f"create shelter failure"
        
        if not animal_id:
            return f"no animal id"

        #TODO: Return example query results. Note: The results returned have
        # to be in the format of a string in order to display properly in the 
        # 'query-out' element. Please separate each result with a newline for
        # readability
        results = shelter.read({'animal_id': animal_id})
        
        if results:
            formatted = "\n\n".join(
                pformat(doc, indent=2, width = 80, sort_dicts=False)
                for doc in results
            )
            return formatted
        else:
            output = f"no reccords found for that animal\n\n"
            return output
# Run app and display result inline in the notebook, note, if you have previously run a prior app, the default port of 8050 may not be available, if so, try setting an alternate port.
app.run_server()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 from dash.dependencies import Input, Output
#       5 from pprint import pprint
# ----> 6 JupyterDash.infer_jupyter_proxy_config()
#       8 # URL Lib to make sure that our input is 'sane'
#       9 import urllib.parse
#
# File ~/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages/jupyter_dash/jupyter_app.py:82, in JupyterDash.infer_jupyter_proxy_config(cls)
#      79     return
#      80 else:
#      81     # Assume classic notebook or JupyterLab
# ---> 82     _request_jupyter_config()
#
# File ~/Desktop/School/CS340/mod4/codio-learning-environment-1/.venv/lib/python3.10/site-packages/jupyter_dash/comms.py:79, in _request_jupyter_config(timeout)
#      76 if _jupyter_comm_response_received():
#      77     break
# ---> 79 if asyncio.iscoroutinefunction(kernel.do_one_iteration):
#      80     loop = asyncio.get_event_loop()
#      81     nest_asyncio.apply(loop)
#
# AttributeError: 'IPythonKernel' object has no attribute 'do_one_iteration'
