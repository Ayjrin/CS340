# %%
# Python Testing Script

#TODO: import for your CRUD module

#TODO: Instantiate an instance of your class

#TODO: Use your create function create a new record in the aac database

#TODO: Use your read funtion to return records from the aac database

# %%
from CRUD_Python_Module import AnimalShelter
import json

# %%
shelter = AnimalShelter()

# %%
new_critter = {
    "age_upon_outcome": "7 years",
    "animal_id": "A999999",
    "animal_type": "Dog",
    "breed": "Husky",
    "color": "Black and White",
    "date_of_birth": "2010-01-27",
    "name": "Scoutie VII",
    "outcome_type": "Adoption",
    "sex_upon_outcome": "Spayed Female"
}

# %%
create_result = shelter.create(new_critter)
print(f"Create result: {create_result}")
# Out:
# Create result: True

# %%
read_result = shelter.read({"name": "Scoutie VII"})
print(json.dumps(read_result, indent=4, default=str))
# Out:
# [
#     {
#         "_id": "690d2434a47010fc3ec0cdc2",
#         "age_upon_outcome": "7 years",
#         "animal_id": "A999999",
#         "animal_type": "Dog",
#         "breed": "Husky",
#         "color": "Black and White",
#         "date_of_birth": "2010-01-27",
#         "name": "Scoutie VII",
#         "outcome_type": "Adoption",
#         "sex_upon_outcome": "Spayed Female",
#         "record_number": 10001
#     }
# ]
